# %% [markdown]
# # Instalando e Importando Bibliotecas

# %% [markdown]
# ### Pandas e Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### NLTK
# * Apoio ao pré-processamento de textos (tokenização, stopwords, radicalização)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('rslp')
from nltk.tokenize import word_tokenize
from nltk.stem.porter import *
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.

# %% [markdown]
# ### Sklearn
# * Construção do Modelo Espaço-Vetorial
# * Medidas de Similaridade

# %% [markdown]
# ### Networkx e Plotly
# * Construção de Redes k-NN
# * Visualização Interativa de Grafos

# %%
import plotly.graph_objects as go
import networkx as nx
from networkx.algorithms import community

# %% [markdown]
# ### Folium (Mapas)

# %%
import folium
from folium.plugins import HeatMap

# %% [markdown]
# ### Dataset

# %%
# !pip install geocoder
# !pip install haversine
import geocoder
from haversine import haversine, Unit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.5 MB/s
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting haversine
#   Downloading haversine-2.7.0-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.7.0

# %%
# (crie a sua se tiver problemas com limites: http://www.geonames.org/export/web-services.html)
key='3eabda_1' # key demo para API do geonames 
cache_geo = {}
cache_geo['BRODOWSKY SP Brazil'] = [-20.9842, -47.6592]
cache_geo['PREF MUN DE ESTANCIA TURISTICA DE PRESIDENTE EPITACEO SP Brazil'] = [-21.7825,-52.1463]
cache_geo['SECRETARIA DE ESTADO DE EDUCACAO DO DISTRITO FEDERAL DF Brazil'] = [-15.7801, -47.9292]
cache_geo['CACHOEIRA GRANDE MA Brazil'] = [-2.9261, -44.0573]
cache_geo['ROSARIO MA Brazil'] = [-2.93997, -44.2408]
cache_geo['LAGOA DO MATO MA Brazil'] = [-2.46667, -44.7]
cache_geo['GUIMARAES MA Brazil'] = [-2.13217, -44.6005]
cache_geo['BRAGANCA PA Brazil'] = [-1.06595, -46.7895]
cache_geo['CHAPADA RS Brazil'] = [-28.0455, -53.0672]
cache_geo['SECRETARIA DE EDUCACAO DO ESTADO DO RIO GRANDE DO SUL RS Brazil'] =  [-30.0277, -51.2287]
cache_geo['SECRETARIA DE EDUCACAO DO ESTADO DO RIO DE JANEIRO RJ Brazil']=[-22.9035, -43.2096]

import time
def get_lat_lng(local, ind):

  if local in cache_geo:
    return ind, cache_geo[local]
  g = geocoder.geonames(local, maxRows=1, key=key)
  num_tries = 0
  while(len(g)<1 and num_tries < 5):
    time.sleep(1)
    g = geocoder.geonames(local, maxRows=1, key=key)
    num_tries+=1
  if (len(g)> 0):
    for result in g:
      gps = [result.lat,result.lng]
      cache_geo[local]=gps
      return ind, gps
  else:
    return ind, []

# %% [markdown]
# ## Baixar planilhas e descompactá-las

# %%
#SP
#!gdown --id 12g9ytu1ytkm8AY3dsayhewDD8AlHQ32v
#!unzip SP_jaro.zip

#AM
#!gdown --id 18lwByeizRy7CkqdMFdXkjKpvK3HdxD-R
#!unzip AM_jaro.zip

#ES
#!gdown --id 1rrklnb_97XQDVR3-JtkWSA251l13U2VQ
#!unzip ES_jaro.zip

#DF
#!gdown --id 1-A_rIMC0F9ReJ-He4ci8I0tzppL3mY2J
#!unzip DF_jaro.zip

#AP
#!gdown --id 1Vkz7kEI_hPwluewpM9shUtCYga3pdLwZ
#!unzip AP_jaro.zip

#AL
#!gdown --id 1_BSrMuNMYM5JU-HZ7pT3YV3_cBvaJfDX
#!unzip AL_jaro.zip
#AC
# !gdown --id 1YBmiuWzZ-qaLqK8DZWa4ZRS8Ej9ZOUVE
# !unzip AC_jaro.zip


#BA
#!gdown --id 1XaW40RQbOcvw8pCrEPwpMRRy52iOelX4
#!unzip BA_jaro.zip

#CE
#!gdown --id 1NVmbeaItpC9Gu9m1teZCEQhTBFIXWMEN
#!unzip CE_jaro.zip

#GO
#!gdown --id 1XPNousihOWzm9y0QuPvdJ6GF-VP-rXKf
#!unzip GO_jaro.zip

#MA
#!gdown --id 13grfjcbEIkZKkx9QjJiWrOD6H78ZX7oT
#!unzip MA_jaro.zip


#MS
#!gdown --id 1-mB6l1CoS42aMB8SGFKrLTF2isOnjAGd
#!unzip MS_jaro.zip

#Mt
#!gdown --id 1lggW1XnAUTfn2PAv3AiqgKlMyOOvdxWC
#!unzip MT_jaro.zip

#PA
#!gdown --id 1kCU1yLpz4_BKZP9D7-9t9roYW8OaQiRU
#!unzip PA_jaro.zip

#PB
#!gdown --id 1Tlsgf8NLDJOzclB8t9T7Zp-xw2H0Ubbr
#!unzip PB_jaro.zip

#PE
#!gdown --id 18vH7x2zWXDBMEvz90KKCLf4auWOnPy6m
#!unzip PE_jaro.zip

#TO
#!gdown --id 12rRiZOJMZuD-q1CZKDD3Am1sQfNw89mt
#!unzip TO_jaro.zip

#MG
#!gdown --id 11YbeBFz1gbZY23p8m8U4kBNAULZtIlWq
#!unzip MG_jaro.zip

#PI
#!gdown --id 1TYhEd9zbdlLKdcs9gEhf-59HIVa5nDsm
#!unzip PI_jaro.zip

#PR
#!gdown --id 1Gh8S1YX9xOgGNGOa2QqSLB7mBTDHGLU5
#!unzip PR_jaro.zip

#RJ
#!gdown --id 1VIqZV8YXZjvGxG9ZcTgQxvMVDC7aT3nh
#!unzip RJ_jaro.zip

#RN
#!gdown --id 1Lhm8qZew7h0D-OvLEgeyaRAdeYTsXmL6
#!unzip RN_jaro.zip

#RO
#!gdown --id 1pwL09NtZmibdWebgejhAzy2kMI9KryAV
#!unzip RO_jaro.zip

#RR
#!gdown --id 1113EkybkYCTDVgBLAvCO6B9dKj_7l3SX
#!unzip RR_jaro.zip

#RS
#!gdown --id 1opd73_iKhHvVAXaMFDqJL6LTudE7aqBV
#!unzip RS_jaro.zip

#SC
#!gdown --id 1-5tqi4-bHEeO5pC5NOdILJx58rY1rmk_
#!unzip SC_jaro.zip

#SE
#!gdown --id 11vWbpGl1NwBzX0GeBDUFn0bdEPQEACXW
#!unzip SE_jaro.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1YBmiuWzZ-qaLqK8DZWa4ZRS8Ej9ZOUVE
# To: /content/AC_jaro.zip
# 100% 4.98M/4.98M [00:00<00:00, 143MB/s]
# Archive:  AC_jaro.zip
#   inflating: AC_jaro0.csv
#   inflating: AC_jaro100.csv
#   inflating: AC_jaro200.csv

# %% [markdown]
# Concatena as planilhas

# %%
import glob
files = sorted(glob.glob('/content/*.csv'))

df1 = []
cont = 0
total = 0
for file in files:
    df1.append(pd.read_csv(file, sep=';'))
    total+=len(df1[cont])
    cont+=1
df = pd.concat(df1, ignore_index=True)
df['município'] = df['município'].str.replace('EMBUGUACU', 'EMBU GUACU')
df['município'] = df['município'].str.replace('MOGIGUACU', 'MOGI GUACU')
df['município'] = df['município'].str.replace('PARIQUERAACU', 'PARIQUERA ACU')
df['município'] = df['município'].str.replace('XIQUEXIQUE', 'XIQUE XIQUE')
df['município'] = df['município'].str.replace('APICUMACU', 'APICUM ACU')
df['município'] = df['município'].str.replace('CONCEICAO DO LAGOACU', 'CONCEICAO DO LAGO ACU')
df['município'] = df['município'].str.replace('TOMEACU', 'TOME ACU')
df['município'] = df['município'].str.replace('IGARAPEACU', 'IGARAPE ACU')
df['município'] = df['município'].str.replace('IGARAPEMIRI', 'IGARAPE MIRI')
df['município'] = df['município'].str.replace('PEIXEBOI', 'PEIXE BOI')
# !rm -r /content/*.csv
# !rm -r /content/*.zip

df = df.dropna(subset=['Energia'])
df['jaro_sim'] = df['jaro_sim'].astype(float)
df = df[df['jaro_sim'] >= 0.85] ## Manter apenas itens com similaridade maior ou igual a 0.85
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8,9,10,11,14,15,16,17,18,19,20,22,23,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8,9,10,11,15,18,20,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Unnamed: 0                           nome do arquivo   município  UF  \
# 0                0  relatorioDocumentosDespesasItens (1).xls  ACRELANDIA  AC
# 2                2  relatorioDocumentosDespesasItens (1).xls  ACRELANDIA  AC
# 3                3  relatorioDocumentosDespesasItens (1).xls  ACRELANDIA  AC
# 4                4  relatorioDocumentosDespesasItens (1).xls  ACRELANDIA  AC
# 6                6  relatorioDocumentosDespesasItens (1).xls  ACRELANDIA  AC
# ...            ...                                       ...         ...  ..
# 142355         758      relatorioDocumentosDespesasItens.xls  ACRELANDIA  AC
# 142356         759      relatorioDocumentosDespesasItens.xls  ACRELANDIA  AC
# 142357         760      relatorioDocumentosDespesasItens.xls  ACRELANDIA  AC
# 142359         762      relatorioDocumentosDespesasItens.xls  ACRELANDIA  AC
# 142361         764      relatorioDocumentosDespesasItens.xls  ACRELANDIA  AC
#
#               data                           item_nota  \
# 0       04/04/2014        farinha de mandioca, torrada
# 2       04/04/2014                  achocolatado em pó
# 3       04/04/2014                     aveia em flocos
# 4       04/04/2014                      feijão carioca
# 6       04/04/2014                     feijão de corda
# ...            ...                                 ...
# 142355  29/08/2013            frango inteiro, com pele
# 142356  24/09/2013  carne bovina, músculo, sem gordura
# 142357  24/09/2013            frango inteiro, com pele
# 142359  30/10/2013  carne bovina, músculo, sem gordura
# 142361  30/10/2013            frango inteiro, com pele
#
#                                        item_taco  jaro_sim  Cat  \
# 0                  farinha, de mandioca, torrada  0.950246  122
# 2                               achocolatado, pó  0.954167  491
# 3                            aveia, flocos, crua  0.864022    7
# 4                           feijão, carioca, cru  0.940000  562
# 6                            feijão, rajado, cru  0.879406  570
# ...                                          ...       ...  ...
# 142355            frango, inteiro, com pele, cru  0.926667  402
# 142356  carne, bovina, músculo, sem gordura, cru  0.922941  372
# 142357            frango, inteiro, com pele, cru  0.926667  402
# 142359  carne, bovina, músculo, sem gordura, cru  0.922941  372
# 142361            frango, inteiro, com pele, cru  0.926667  402
#
#                    Umidade  ...                Cobre               Zinco  \
# 0                     8.34  ...                   Tr                0.36
# 2       1.1033333333333335  ...                 0.56                1.04
# 3        9.133333333333333  ...                 0.44                2.63
# 4       13.996666666666668  ...                 0.79   2.903333333333333
# 6       14.963333333333333  ...   0.8443333333333333  2.5966666666666662
# ...                    ...  ...                  ...                 ...
# 142355               66.54  ...                 0.04  1.1233333333333333
# 142356   72.35333333333334  ...  0.05333333333333334                3.65
# 142357               66.54  ...                 0.04  1.1233333333333333
# 142359   72.35333333333334  ...  0.05333333333333334                3.65
# 142361               66.54  ...                 0.04  1.1233333333333333
#
#        Retinol    RE  RAE               Tiamina          Riboflavina  \
# 0          NaN   NaN   NaN                   Tr                   Tr
# 2       795.85   NaN   NaN                 1.38                 1.02
# 3          NaN   NaN   NaN   0.5533333333333333                 0.03
# 4          NaN   NaN   NaN  0.16666666666666666                   Tr
# 6          NaN   NaN   NaN                 0.07                 0.03
# ...        ...   ...   ...                  ...                  ...
# 142355       7     7     7                 0.08                 0.03
# 142356    1.91  1.91  1.91  0.09333333333333334  0.18666666666666668
# 142357       7     7     7                 0.08                 0.03
# 142359    1.91  1.91  1.91  0.09333333333333334  0.18666666666666668
# 142361       7     7     7                 0.08                 0.03
#
#                  Piridoxina             Niacina Vitamina C
# 0        0.8066666666666666                  Tr         Tr
# 2        1.5233333333333334   4.986666666666667         Tr
# 3                        Tr                4.47       1.35
# 4                      0.65   4.023333333333333
# 6       0.06666666666666667                  Tr         Tr
# ...                     ...                 ...        ...
# 142355                   Tr   3.276666666666667        NaN
# 142356                 0.04  2.7866666666666666        NaN
# 142357                   Tr   3.276666666666667        NaN
# 142359                 0.04  2.7866666666666666        NaN
# 142361                   Tr   3.276666666666667        NaN
#
# [76485 rows x 36 columns]

# %% [markdown]
# Baixar e descompactar latitude e longitude dos municípios de São Paulo e Amazonas

# %%
# !gdown --id 17HAV__twjFpIHzJbgDL5flkEzBhIxLBq
location = pd.read_csv('/content/SP_AM_location.csv')
for index,row in location.iterrows():
  cache_geo[row['local']] = [float(row['latitude']), float(row['longitude'])]
# !rm /content/SP_AM_location.csv
#cache_geo
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=17HAV__twjFpIHzJbgDL5flkEzBhIxLBq
# To: /content/SP_AM_location.csv
# 100% 28.3k/28.3k [00:00<00:00, 30.5MB/s]

# %% [markdown]
# # Exemplo de Alinhamento NFE-TACO
#
# https://docs.google.com/spreadsheets/d/1Trl8sfKe1UliMDtm9pvYp4fQs2ha3_DZdU09FWrGkmI/edit?usp=sharing

# %% [markdown]
# ### Mapa - Geral

# %%
# plotando documentos no mapa
campo_taco = 'Energia'
min_jaro = 0.85
total = {}
indicador = {}
max_v = 0

for index,row in df.iterrows():
  if float(row['jaro_sim']) < min_jaro: continue
  local = row['município']+' '+	row['UF']+' Brazil'

  if local not in indicador: 
    indicador[local]=0
    total[local] = 0
  try:
      v = float(row[campo_taco])
      indicador[local]+=v
      total[local]+=1
      if indicador[local] > max_v: max_v = indicador[local]
  except:
    1

# %%
m = folium.Map([-14.5931291,-56.6985808], zoom_start=4)
latitude = []
longitude = []
data_heatmap = []
cont = 0
ind = 0
score = []
for local in indicador:
  #print(cont, ' of ', len(indicador))
  ind, gps = get_lat_lng(local, ind)
  if (len(gps)>0):
    lat = gps[0]
    latitude.append(lat)
    lng = gps[1]
    longitude.append(lng)
    score.append(indicador[local])
    text = local+' '+campo_taco+' = '+str(indicador[local])#+' media = '+str(indicador[local]/total[local])
    data_heatmap.append([lat,lng, max_v - indicador[local]])
    folium.Marker([lat, lng], popup=text).add_to(m)
  else:
    print('Error city ', local, ' not found')
  cont+=1
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_710e585d76e1403ee45f531e747e4b31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_710e585d76e1403ee45f531e747e4b31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_710e585d76e1403ee45f531e747e4b31 = L.map(
#                 &quot;map_710e585d76e1403ee45f531e747e4b31&quot;,
#                 {
#                     center: [-14.5931291, -56.6985808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d37679be81a7a2903e8c4f091cb3bd9f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#             var marker_1a8f00d742dd349cb06b6b5c2da1b81a = L.marker(
#                 [-9.98045, -66.84388],
#                 {}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#         var popup_8a0ed73e21858fadb3b8d8333b7aa95a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_190bc215af0f6b3bc7a68cb131c68404 = $(`&lt;div id=&quot;html_190bc215af0f6b3bc7a68cb131c68404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ACRELANDIA AC Brazil Energia = 223709.18416092006&lt;/div&gt;`)[0];
#             popup_8a0ed73e21858fadb3b8d8333b7aa95a.setContent(html_190bc215af0f6b3bc7a68cb131c68404);
#
#
#         marker_1a8f00d742dd349cb06b6b5c2da1b81a.bindPopup(popup_8a0ed73e21858fadb3b8d8333b7aa95a)
#         ;
#
#
#
#
#             var marker_a111712d54b9a616b0fa7e2134f15929 = L.marker(
#                 [-10.88334, -70.01314],
#                 {}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#         var popup_1d873e6d5f0cbd87c2eb315036b3838c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3df57aca960d421647205d20fd185558 = $(`&lt;div id=&quot;html_3df57aca960d421647205d20fd185558&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSIS BRASIL AC Brazil Energia = 134233.86977282978&lt;/div&gt;`)[0];
#             popup_1d873e6d5f0cbd87c2eb315036b3838c.setContent(html_3df57aca960d421647205d20fd185558);
#
#
#         marker_a111712d54b9a616b0fa7e2134f15929.bindPopup(popup_1d873e6d5f0cbd87c2eb315036b3838c)
#         ;
#
#
#
#
#             var marker_0ebd0568d3ea5f96de9564d41e57f8dd = L.marker(
#                 [-9.18989, -72.56853],
#                 {}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#         var popup_8a4a2f31faa48fa52bf91d73e7634722 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_81dbf534da59f1e1ba8ceaf9cd27e432 = $(`&lt;div id=&quot;html_81dbf534da59f1e1ba8ceaf9cd27e432&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MARECHAL THAUMATURGO AC Brazil Energia = 913371.4637701662&lt;/div&gt;`)[0];
#             popup_8a4a2f31faa48fa52bf91d73e7634722.setContent(html_81dbf534da59f1e1ba8ceaf9cd27e432);
#
#
#         marker_0ebd0568d3ea5f96de9564d41e57f8dd.bindPopup(popup_8a4a2f31faa48fa52bf91d73e7634722)
#         ;
#
#
#
#
#             var marker_bf18cd7c2868be0013e8bda0521db822 = L.marker(
#                 [-11.01611, -68.74806],
#                 {}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#         var popup_13c2988a0997f3effb42a642952784ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6c8e802136cefd4403a67a18d1a5db03 = $(`&lt;div id=&quot;html_6c8e802136cefd4403a67a18d1a5db03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BRASILEIA AC Brazil Energia = 1449548.0483903955&lt;/div&gt;`)[0];
#             popup_13c2988a0997f3effb42a642952784ec.setContent(html_6c8e802136cefd4403a67a18d1a5db03);
#
#
#         marker_bf18cd7c2868be0013e8bda0521db822.bindPopup(popup_13c2988a0997f3effb42a642952784ec)
#         ;
#
#
#
#
#             var marker_c56d8013b974dba3e7cf43f762c85904 = L.marker(
#                 [-9.57859, -68.17197],
#                 {}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#         var popup_ad8cd29f746468aa4ab8199ead4318f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c2b57670c2a5c62721bd19156be12739 = $(`&lt;div id=&quot;html_c2b57670c2a5c62721bd19156be12739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BUJARI AC Brazil Energia = 67356.31205130245&lt;/div&gt;`)[0];
#             popup_ad8cd29f746468aa4ab8199ead4318f5.setContent(html_c2b57670c2a5c62721bd19156be12739);
#
#
#         marker_c56d8013b974dba3e7cf43f762c85904.bindPopup(popup_ad8cd29f746468aa4ab8199ead4318f5)
#         ;
#
#
#
#
#             var marker_49aeb9f272acb9a2b0c752c9662d7199 = L.marker(
#                 [-10.48782, -67.84831],
#                 {}
#             ).addTo(map_710e585d76e1403ee45f531e747e4b31);
#
#
#         var popup_50acfd2eedd408658f966acba887e

# %% [markdown]
# ## Salva em arquivo a latitude, longitude e o somatório das energias(kcal) - Desabilitado

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
#location = pd.DataFrame(list(zip(indicador, latitude, longitude, score)), columns = ['local', 'latitude', 'longitude', 'score'])
#location.to_csv('/content/gdrive/MyDrive/AC_location.csv')

# %%
m = folium.Map([-14.5931291,-56.6985808], zoom_start=4)
HeatMap(data_heatmap).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bf68a4d847a95e85d197b0db5019f92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bf68a4d847a95e85d197b0db5019f92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9bf68a4d847a95e85d197b0db5019f92 = L.map(
#                 &quot;map_9bf68a4d847a95e85d197b0db5019f92&quot;,
#                 {
#                     center: [-14.5931291, -56.6985808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6368e2f6f20babc9b8940577928edb1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9bf68a4d847a95e85d197b0db5019f92);
#
#
#             var heat_map_d7b4b5736a80c371950c36709f34993c = L.heatLayer(
#                 [[-9.98045, -66.84388, 8131769.045280738], [-10.88334, -70.01314, 8221244.359668828], [-9.18989, -72.56853, 7442106.765671492], [-11.01611, -68.74806, 6905930.181051262], [-9.57859, -68.17197, 8288121.917390355], [-10.48782, -67.84831, 8146217.270088778], [-7.62759, -72.67756, 0.0], [-10.93542, -68.44411, 6140642.347830383], [-8.16438, -70.35286, 8202539.867651129], [-9.09166, -71.84069, 7721551.752259327], [-7.53963, -73.45826, 7994434.11736613], [-9.48951, -70.01242, 7860235.379735967], [-10.29428, -67.26817, 8083290.974029423], [-9.65038, -67.77733, 8139857.788704103], [-8.26861, -72.74389, 8019392.519625981], [-9.97472, -67.81, 7318492.78274194], [-7.85286, -73.23613, 7819784.4210755285], [-9.4773, -70.39032, 8123365.472344175], [-10.03565, -69.54974, 7950369.090704346], [-9.9408, -67.39314, 8098803.151532203], [-8.16139, -70.76556, 8093173.607320799], [-10.59663, -68.64891, 8177259.595105494]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_9bf68a4d847a95e85d197b0db5019f92);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
