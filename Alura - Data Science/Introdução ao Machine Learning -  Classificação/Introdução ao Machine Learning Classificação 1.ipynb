# %%
# features dos animais
# Pelo longo?
# Perna curta?
# Faz AuAu ?

porco1 = [0, 1, 0]
porco2 = [0, 1, 1]
porco3 = [1, 1, 0]

cachorro1 = [0, 1, 1]
cachorro2 = [1, 0, 1]
cachorro3 = [1, 1, 1]

X_train = [porco1, porco2, porco3, cachorro1, cachorro2, cachorro3]

# Classes
# 0 -> Cachorro
# 1 -> Porco
y_train = [1, 1, 1, 0, 0, 0]

misterio1 = [1,1,1]
misterio2 = [1,1,0]
misterio3 = [0,1,1]

X_test = [misterio1,misterio2,misterio3]
y_test = [0,1,1]

# %%
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(dados, classes)
# Out:
# LinearSVC()

# %%
animal_misterioso = [1,1,1]

model.predict([animal_misterioso])
# Out:
# array([0])

# %%
previsoes = model.predict(X_test)

# %%
corretos = (previsoes == y_test).sum()
total = len(X_test)

taxa_de_acertos = corretos/total *100
print(f"{taxa_de_acertos:.2f} %")
# Out:
# 66.67 %

# %%
from sklearn.metrics import accuracy_score

taxa_de_acertos = accuracy_score(y_test, previsoes)
print(f"{taxa_de_acertos*100:.2f} %")
# Out:
# 66.67 %
